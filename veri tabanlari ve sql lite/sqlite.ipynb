# %%
# %%!
# pip install --trusted-host pypi.org ipython-sql
# Out:
# ['Requirement already satisfied: ipython-sql in c:\\users\\lenovo\\anaconda3\\lib\\site-packages (0.4.0)',
#  'Requirement already satisfied: six in c:\\users\\lenovo\\anaconda3\\lib\\site-packages (from ipython-sql) (1.15.0)',
#  'Requirement already satisfied: ipython>=1.0 in c:\\users\\lenovo\\anaconda3\\lib\\site-packages (from ipython-sql) (7.16.1)',
#  'Requirement already satisfied: prettytable<1 in c:\\users\\lenovo\\anaconda3\\lib\\site-packages (from ipython-sql) (0.7.2)',
#  'Requirement already satisfied: ipython-genutils>=0.1.0 in c:\\users\\lenovo\\anaconda3\\lib\\site-packages (from ipython-sql) (0.2.0)',
#  'Requirement already satisfied: sqlparse in c:\\users\\lenovo\\anaconda3\\lib\\site-packages (from ipython-sql) (0.4.2)',
#  'Requirement already satisfied: sqlalchemy>=0.6.7 in c:\\users\\lenovo\\anaconda3\\lib\\site-packages (from ipython-sql) (1.3.18)',
# ...

# %%
# %load_ext sql

# %%
# %sql sqlite:///vbo.db

# %%
# %%sql
# SELECT*FROM Customers LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %% [markdown]
# # Manuel Tablo Olusturma Islemleri

# %%
# %%sql
# CREATE TABLE news_tablo(firstname varchar(20),
#                        lastname varchar(20));
# Out:
#  * sqlite:///vbo.db
# (sqlite3.OperationalError) table news_tablo already exists
# [SQL: CREATE TABLE news_tablo(firstname varchar(20),
#                        lastname varchar(20));]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# %%sql
# INSERT INTO news_tablo values('Ali','Uzaya_Git');
# Out:
#  * sqlite:///vbo.db
# 1 rows affected.
# []

# %%
# %%sql
# SELECT*FROM news_tablo;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Ali', 'Uzaya_Git'), ('Isik', 'Sute_devam'), ('Ali', 'Uzaya_Git')]

# %%
# %%sql
# INSERT INTO news_tablo values('Isik','Sute_devam');
# Out:
#  * sqlite:///vbo.db
# 1 rows affected.
# []

# %%
# %%sql
# SELECT*FROM news_tablo;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Ali', 'Uzaya_Git'),
#  ('Isik', 'Sute_devam'),
#  ('Ali', 'Uzaya_Git'),
#  ('Isik', 'Sute_devam')]

# %% [markdown]
# # Select-İşlemleri

# %%
# %%sql
# SELECT* FROM Products LIMIT 5;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21)]

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Products',),
#  ('Categories',),
#  ('Customers',),
#  ('Employees',),
#  ('OrderDetails',),
#  ('Orders',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('yeni_tablo',),
#  ('new_tablo',),
#  ('news_tablo',)]

# %%
# %%sql
# SELECT*FROM Customers where 1=0;
# # degişkenler isimlerine erişme işlemi yapmış olduk
# Out:
#  * sqlite:///vbo.db
# Done.
# (sqlite3.OperationalError) near "#degişkenler": syntax error
# [SQL: #degişkenler isimlerine erişme işlemi yapmış olduk]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# %%sql
# SELECT*FROM Customers LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
# %%sql
# SELECT CustomerName,City,from Customers LIMIT 5;
# # Bu da başka bir şekilde erişme şeklidir
# Out:
#  * sqlite:///vbo.db
# (sqlite3.OperationalError) near "from": syntax error
# [SQL: SELECT CustomerName,City,from Customers LIMIT 5;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# %%sql
# SELECT CustomerName,City,Country FROM Customers LIMIT 5;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Alfreds Futterkiste', 'Berlin', 'Germany'),
#  ('Ana Trujillo Emparedados y helados', 'México D.F.', 'Mexico'),
#  ('Antonio Moreno Taquería', 'México D.F.', 'Mexico'),
#  ('Around the Horn', 'London', 'UK'),
#  ('Berglunds snabbköp', 'Luleå', 'Sweden')]

# %% [markdown]
# # Select İşlemi-2

# %%
# %%sql
# SELECT Price,Price*3,Price*3-100 from Products LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(18, 54, -46), (19, 57, -43), (10, 30, -70)]

# %%
#degişkenlere takma isim takma işlemi yapma 
#alias:takma isim,kısayol

# %%
# %%sql
# SELECT Price,Price*3,Price*3-100 AS islemli_price from Products LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(18, 54, -46), (19, 57, -43), (10, 30, -70)]

# %%
#3 unu birden degişitime işlemi yapmak istersek

# %%
# %%sql
# SELECT Price AS ilk_price,Price*3 AS yeni_price,Price*3-100 AS islemli_price from Products LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(18, 54, -46), (19, 57, -43), (10, 30, -70)]

# %%
# count 
#saymak anlamına gelir 
#bir select işlemidir

# %%
# %%sql
# SELECT COUNT(*)AS satir_sayisi FROM Customers;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(91,)]

# %%
#orderby =>sıralama işlemi kullanılır

# %%
#küçükten buyuge sıralama işlemi yaptık

# %%
# %%sql
# SELECT*from Products ORDER BY Price LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(13, 'Konbu', 6, 8, '2 kg box', 6),
#  (52, 'Filo Mix', 24, 5, '16 - 2 kg boxes', 7),
#  (23, 'Tunnbröd', 9, 5, '12 - 250 g pkgs.', 9),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10),
#  (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10),
#  (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12),
#  (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13),
#  (77, 'Original Frankfurter grüne Soße', 12, 2, '12 boxes', 13),
#  (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14)]

# %%
#buyukten kucuge sıralama yapmak istersek

# %%
# %%sql
# SELECT*from Products ORDER BY Price DESC LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(31, 'Gorgonzola Telino', 14, 4, '12 - 100 g pkgs', 435),
#  (38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263),
#  (29, 'Thüringer Rostbratwurst', 12, 6, '50 bags x 30 sausgs.', 123),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81),
#  (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62),
#  (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55),
#  (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53),
#  (62, 'Tarte au sucre', 29, 3, '48 pies', 49),
#  (43, 'Ipoh Coffee', 20, 1, '16 - 500 g tins', 46)]

# %% [markdown]
# # Where
#
# tablolarda filitreleme işlemi yapmak için kullanılır
#
# degişkenlerin degerlerine göre gözlemler seçim işlemi yapmak için kullanılan bir araçtır

# %%
# %%sql
# SELECT*FROM Customers LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
# ...

# %%
#ülkesi isviçre olanları seçmek istersek 
#asagidaki text ya da string secim islemi demektir 
#country de kisitin ne anlamina gelir

# %%
# %%sql
# SELECT*FROM Customers WHERE Country="Sweden";
# Out:
#  * sqlite:///vbo.db
# Done.
# [(5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (24, 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')]

# %%
#asagidaki ifade ile berlin olmayanlari not ile getirme islemi yaptik

# %%
# %%sql
# SELECT*FROM Customers WHERE NOT City="Berlin";
# Out:
#  * sqlite:///vbo.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
# ...

# %%
#numerik islemler icin kisit secersek

# %%
# %%sql
# SELECT*FROM Customers Where PostalCode=5021;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico')]

# %%
#buyuktur ve kucuktur isleminide yapabiliriz

# %%
# %%sql
# SELECT*FROM Customers Where PostalCode>5021;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK'),
# ...

# %%
#Where-2 And ve Or ifadelerine giris

# %%
#asagidaki ulkesi UK sehri london olanlarin verisini bize getirdi
#and ifadesi ayni anda saglamasina bakar

# %%
# %%sql
# SELECT*FROM Customers WHERE Country='UK' AND City='London';
# Out:
#  * sqlite:///vbo.db
# Done.
# [(4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK'),
#  (19, 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK'),
#  (53, 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK'),
#  (72, 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')]

# %%
# %%sql
# SELECT*FROM Customers WHERE Country='UK' OR Country='USA';
# Out:
#  * sqlite:///vbo.db
# Done.
# [(4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK'),
#  (19, 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK'),
#  (32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (38, 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
# ...

# %%
#ulke icin bir kisit ama sehir icin birden fazla kisit getirmek istersek

# %%
# %%sql
# SELECT*FROM Customers WHERE Country='USA' AND(City='Eugene' OR City='Elgin');
# Out:
#  * sqlite:///vbo.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')]

# %%
#yukaridaki degiskene birde sayisal kisit katmnak istersek

# %%
# %%sql
# SELECT*FROM Customers WHERE Country='USA' AND PostalCode=97403 AND (City='Eugene' OR City='Elgin');
# Out:
#  * sqlite:///vbo.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')]

# %%
#in / not in  kullanimi

# %%
# %%sql
# SELECT*FROM Customers WHERE CustomerID in (1,3,5,7);
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France')]

# %%
#gelmesini istemedigimiz gozlemler icin

# %%
# %%sql
# SELECT*FROM Customers WHERE CustomerID NOT in (1,3,5,7);
# Out:
#  * sqlite:///vbo.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (12, 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
# ...

# %% [markdown]
# ![image.png](attachment:c3bb210b-8581-43a2-bbc0-daf8c8b2d187.png)

# %%
# %%sql
# SELECT*FROM Customers Where CustomerName LIKE '%or%' LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (40, "La corne d'abondance", 'Daniel Tonini', "67, avenue de l'Europe", 'Versailles', '78000', 'France'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (52, 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '4179', 'Germany'),
#  (53, 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK'),
#  (55, 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA'),
#  (72, 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK'),
# ...

# %%
#ne ile basladigi onemli degil ama bittigi sey benim icin onemli ise

# %%
# %%sql
# SELECT* FROM Customers WHERE CustomerName LIKE '%a' LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (30, 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero, 33', 'Sevilla', '41101', 'Spain'),
#  (61, 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora, 12', 'Rio de Janeiro', '02389-673', 'Brazil'),
#  (62, 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios, 891', 'São Paulo', '05487-020', 'Brazil'),
#  (88, 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado, 12', 'Resende', '08737-363', 'Brazil'),
#  (90, 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')]

# %%
#notlari oldugu gibi alip kopyalasak bile hata alabiliriz

# %%
# %%sql
# SELECT*FROM Customers WHERE CustomerName LIKE 'A%' AND Country LIKE '%o';
# Out:
#  * sqlite:///vbo.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %% [markdown]
# # Between

# %%
#degeri 10 ila 20 arasinda olanlara erismek istersek

# %%
# %%sql
# SELECT*FROM Products WHERE Price BETWEEN 10 AND 20  LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (16, 'Pavlova', 7, 3, '32 - 500 g boxes', 17),
#  (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10),
#  (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14),
#  (34, 'Sasquatch Ale', 16, 1, '24 - 12 oz bottles', 14),
#  (35, 'Steeleye Stout', 16, 1, '24 - 12 oz bottles', 18),
#  (36, 'Inlagd Sill', 17, 8, '24 - 250 g jars', 19),
#  (39, 'Chartreuse verte', 18, 1, '750 cc per bottle', 18)]

# %%
#degeri 10 ila 20 arasinda olmayanlara erismek istersek

# %%
# %%sql
# SELECT *FROM Products WHERE Price NOT BETWEEN 10 AND 20 LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31),
#  (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21),
#  (12, 'Queso Manchego La Pastora', 5, 4, '10 - 500 g pkgs.', 38),
#  (13, 'Konbu', 6, 8, '2 kg box', 6)]

# %%
# %%sql
# SELECT *FROM Products WHERE (Price BETWEEN 10 AND 20) AND NOT CategoryID IN(1,2,3) LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(36, 'Inlagd Sill', 17, 8, '24 - 250 g jars', 19),
#  (42, 'Singaporean Hokkien Fried Mee', 20, 5, '32 - 1 kg pkgs.', 14),
#  (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12),
#  (54, 'Tourtière', 25, 6, '16 pies', 16),
#  (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13),
#  (73, 'Röd Kaviar', 17, 8, '24 - 150 g jars', 15),
#  (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10)]

# %%
#product name kolayca getirmek istersek

# %%
# %%sql
# SELECT ProductName FROM Products WHERE (Price BETWEEN 10 AND 20) AND NOT CategoryID IN(1,2,3) LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Inlagd Sill',),
#  ('Singaporean Hokkien Fried Mee',),
#  ('Spegesild',),
#  ('Tourtière',),
#  ('Escargots de Bourgogne',),
#  ('Röd Kaviar',),
#  ('Longlife Tofu',)]

# %%
# %%sql
# SELECT * FROM Products WHERE ProductName BETWEEN 'Carnarvon Tigers';
# Out:
#  * sqlite:///vbo.db
# (sqlite3.OperationalError) near ";": syntax error
# [SQL: SELECT * FROM Products WHERE ProductName BETWEEN 'Carnarvon Tigers';]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# # AGGREGATION FONKSIYONLARI:TEMEL ISTATISTIKSEL ISLEMLER

# %%
# %%sql
# SELECT*FROM Products LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31)]

# %%
# %%sql
# SELECT MIN(PRICE) FROM Products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(6,)]

# %%
# %%sql
# SELECT MAX(PRICE) FROM Products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(435,)]

# %%
# %%sql
# SELECT MIN(PRICE),MAX(PRICE) FROM Products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(6, 435)]

# %%
# %%sql
# SELECT MIN(PRICE) AS min_fiyat ,MAX(PRICE) AS max_fiyat FROM Products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(6, 435)]

# %%
#ortalama degeri

# %%
# %%sql
# SELECT AVG(Price)FROM Products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(39.15584415584416,)]

# %%
# %%sql
# SELECT SUM(Price)FROM Products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3015,)]

# %%
#herbir degisken icin ayri ayri almak istersek,bir degiskene iliskin betimsel istatistiksel degerleri alalim

# %%
# %%sql
# SELECT MIN(PRICE),MAX(PRICE),AVG(PRICE),SUM(PRICE) From Products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(6, 435, 39.15584415584416, 3015)]

# %% [markdown]
# # Group BY and Aggregation Fonksiyonlari

# %%
# %%sql
# SELECT*FROM Customers LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
#sql tarfinda yapip sonra pandas tarfina gelmemiz lazim

# %%
# %%sql
# SELECT COUNT(CustomerID),Country FROM Customers GROUP BY Country;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Argentina'),
#  (2, 'Austria'),
#  (2, 'Belgium'),
#  (9, 'Brazil'),
#  (3, 'Canada'),
#  (2, 'Denmark'),
#  (2, 'Finland'),
#  (11, 'France'),
#  (11, 'Germany'),
#  (1, 'Ireland'),
#  (3, 'Italy'),
#  (5, 'Mexico'),
#  (1, 'Norway'),
#  (1, 'Poland'),
#  (2, 'Portugal'),
#  (5, 'Spain'),
#  (2, 'Sweden'),
#  (2, 'Switzerland'),
#  (7, 'UK'),
#  (13, 'USA'),
#  (4, 'Venezuela')]

# %%
# %%sql
# SELECT COUNT(*),Country FROM Customers GROUP BY Country;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Argentina'),
#  (2, 'Austria'),
#  (2, 'Belgium'),
#  (9, 'Brazil'),
#  (3, 'Canada'),
#  (2, 'Denmark'),
#  (2, 'Finland'),
#  (11, 'France'),
#  (11, 'Germany'),
#  (1, 'Ireland'),
#  (3, 'Italy'),
#  (5, 'Mexico'),
#  (1, 'Norway'),
#  (1, 'Poland'),
#  (2, 'Portugal'),
#  (5, 'Spain'),
#  (2, 'Sweden'),
#  (2, 'Switzerland'),
#  (7, 'UK'),
#  (13, 'USA'),
#  (4, 'Venezuela')]

# %%
# buyuktten kucuge siralamak istersek

# %%
# %%sql
# SELECT COUNT(CustomerID),Country FROM Customers GROUP BY Country ORDER BY CustomerID DESC;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Poland'),
#  (2, 'Finland'),
#  (2, 'Denmark'),
#  (1, 'Norway'),
#  (2, 'Belgium'),
#  (1, 'Ireland'),
#  (4, 'Venezuela'),
#  (13, 'USA'),
#  (2, 'Portugal'),
#  (3, 'Italy'),
#  (2, 'Austria'),
#  (9, 'Brazil'),
#  (2, 'Switzerland'),
#  (3, 'Argentina'),
#  (3, 'Canada'),
#  (5, 'Spain'),
#  (11, 'France'),
#  (2, 'Sweden'),
#  (7, 'UK'),
#  (5, 'Mexico'),
#  (11, 'Germany')]

# %%
# %%sql
# SELECT* FROM Products LIMIT 2;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19)]

# %%
# %%sql
# SELECT AVG(Price) As ORT_FIYAT,CategoryID FROM Products GROUP BY CategoryID;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(42.75, 1),
#  (28.25, 2),
#  (33.76923076923077, 3),
#  (74.9, 4),
#  (23.571428571428573, 5),
#  (55.166666666666664, 6),
#  (32.2, 7),
#  (26.5, 8)]

# %%
# %%sql
# SELECT*FROM Categories LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (3, 'Confections', 'Desserts, candies, and sweet breads')]

# %%
# %%sql
# SELECT*FROM Products LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10)]

# %% [markdown]
# # left Join

# %%
# products tablosunu categori tablosunu birlestirme yapicaz

# %%
# %%sql
# SELECT*FROM Products LEFT OUTER JOIN Categories ON Products.CategoryID=Categories.CategoryID LIMIT 5;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings')]

# %%
#daha duzgun bir sekilde birlestirme yaparsak

# %%
# %%sql
# SELECT Products.ProductName,Categories.CategoryID,Categories.CategoryName From Products LEFT OUTER JOIN Categories  ON Products.CategoryID=Categories.CategoryID LIMIT 5;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Chais', 1, 'Beverages'),
#  ('Chang', 1, 'Beverages'),
#  ('Aniseed Syrup', 2, 'Condiments'),
#  ("Chef Anton's Cajun Seasoning", 2, 'Condiments'),
#  ("Chef Anton's Gumbo Mix", 2, 'Condiments')]

# %%
#bir usteki kodu daha da kisaltmaya calistik onu da kisaltma isimlerle yaptik

# %%
# %%sql
# SELECT  PR.ProductName,CA.CategoryID,CA.CategoryName From Products AS PR LEFT OUTER JOIN Categories AS CA ON  PR.CategoryID=CA.CategoryID LIMIT 5;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Chais', 1, 'Beverages'),
#  ('Chang', 1, 'Beverages'),
#  ('Aniseed Syrup', 2, 'Condiments'),
#  ("Chef Anton's Cajun Seasoning", 2, 'Condiments'),
#  ("Chef Anton's Gumbo Mix", 2, 'Condiments')]

# %% [markdown]
# # inner Join

# %%
# %%sql
# SELECT*FROM Customers LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
#siparis verenlerin siparisID ve siparis isimlerine ulasmak istersek

# %%
# %%sql
# SELECT Orders.OrderID,Customers.CustomerName From Orders INNER JOIN Customers ON Orders.CustomerID=Customers.CustomerID;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(10248, 'Wilman Kala'),
#  (10249, 'Tradição Hipermercados'),
#  (10250, 'Hanari Carnes'),
#  (10251, 'Victuailles en stock'),
#  (10252, 'Suprêmes délices'),
#  (10253, 'Hanari Carnes'),
#  (10254, 'Chop-suey Chinese'),
#  (10255, 'Richter Supermarkt'),
#  (10256, 'Wellington Importadora'),
#  (10257, 'HILARIÓN-Abastos'),
#  (10258, 'Ernst Handel'),
#  (10259, 'Centro comercial Moctezuma'),
#  (10260, 'Old World Delicatessen'),
#  (10261, 'Que Delícia'),
#  (10262, 'Rattlesnake Canyon Grocery'),
#  (10263, 'Ernst Handel'),
#  (10264, 'Folk och fä HB'),
#  (10265, 'Blondel père et fils'),
#  (10266, 'Wartian Herkku'),
#  (10267, 'Frankenversand'),
#  (10268, 'GROSELLA-Restaurante'),
#  (10269, 'White Clover Markets'),
#  (10270, 'Wartian Herkku'),
#  (10271, 'Split Rail Beer & Ale'),
#  (10272, 'Rattlesnake Canyon Grocery'),
#  (10273, 'QUICK-Stop'),
#  (10274, 'Vins et alcools Chevalier'),
#  (10275, 'Magazzini Alimentari Riuniti'),
# ...

# %%
#yukaridaki dogrulamak icin isleme count atarak bakabiliriz

# %%
# %%sql
# SELECT COUNT(*) FROM (SELECT Orders.OrderID,Customers.CustomerName From Orders INNER JOIN Customers ON Orders.CustomerID=Customers.CustomerID);
# Out:
#  * sqlite:///vbo.db
# Done.
# [(196,)]

# %% [markdown]
# # NOT:veri manipulasyon islemlerini mumkun oldugu kadariyla sql ortamlarinda yapmaya calis ondan sonra tidy hale getirilmis verileri getirelim ki burada problem olmasin
