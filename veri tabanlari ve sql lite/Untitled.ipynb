# %% [markdown]
# # SQL ve Pandas DataFrame Operasyonlari

# %%
import pandas as pd

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///vbo.db

# %%
# %%sql
# SELECT COUNT(CustomerID),Country FROM Customers GROUP BY Country;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Argentina'),
#  (2, 'Austria'),
#  (2, 'Belgium'),
#  (9, 'Brazil'),
#  (3, 'Canada'),
#  (2, 'Denmark'),
#  (2, 'Finland'),
#  (11, 'France'),
#  (11, 'Germany'),
#  (1, 'Ireland'),
#  (3, 'Italy'),
#  (5, 'Mexico'),
#  (1, 'Norway'),
#  (1, 'Poland'),
#  (2, 'Portugal'),
#  (5, 'Spain'),
#  (2, 'Sweden'),
#  (2, 'Switzerland'),
#  (7, 'UK'),
#  (13, 'USA'),
#  (4, 'Venezuela')]

# %%
df=%sql SELECT COUNT(CustomerID),Country FROM Customers GROUP BY Country;
# Out:
#  * sqlite:///vbo.db
# Done.

# %%
df
# Out:
# [(3, 'Argentina'),
#  (2, 'Austria'),
#  (2, 'Belgium'),
#  (9, 'Brazil'),
#  (3, 'Canada'),
#  (2, 'Denmark'),
#  (2, 'Finland'),
#  (11, 'France'),
#  (11, 'Germany'),
#  (1, 'Ireland'),
#  (3, 'Italy'),
#  (5, 'Mexico'),
#  (1, 'Norway'),
#  (1, 'Poland'),
#  (2, 'Portugal'),
#  (5, 'Spain'),
#  (2, 'Sweden'),
#  (2, 'Switzerland'),
#  (7, 'UK'),
#  (13, 'USA'),
#  (4, 'Venezuela')]

# %%
#pandas dataframe seklinde bakalbilmek icin

# %%
dff=pd.DataFrame(df,columns=["MUS_SAY","ULKE"])

# %%
dff
# Out:
#     MUS_SAY         ULKE
# 0         3    Argentina
# 1         2      Austria
# 2         2      Belgium
# 3         9       Brazil
# 4         3       Canada
# 5         2      Denmark
# 6         2      Finland
# 7        11       France
# 8        11      Germany
# 9         1      Ireland
# 10        3        Italy
# 11        5       Mexico
# 12        1       Norway
# 13        1       Poland
# 14        2     Portugal
# 15        5        Spain
# 16        2       Sweden
# 17        2  Switzerland
# 18        7           UK
# 19       13          USA
# 20        4    Venezuela

# %%
dff.head()
# Out:
#    MUS_SAY       ULKE
# 0        3  Argentina
# 1        2    Austria
# 2        2    Belgium
# 3        9     Brazil
# 4        3     Canada

# %%
dff.plot.barh(x="ULKE",y="MUS_SAY");
