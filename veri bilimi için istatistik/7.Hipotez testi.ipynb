# %% [markdown]
# #### **hipotezler ve türleri-p-value-HİPOTEZ TESTİ ADIMLARI-tek örneklem t testi-iş uygulaması(ürün satın alma adım optimizasyonu)**
#
# ![image.png](attachment:0e52e663-fe70-4682-811f-3940cd3b5ecd.png)
# mü=> anakitle ortalaması

# %% [markdown]
# **Hata Tipleri**
# ![image.png](attachment:9e68b4b9-5806-4fd9-9eeb-07201cad1eff.png)

# %% [markdown]
# **p-value**
#
# ![image.png](attachment:907db3db-9307-481a-856e-34a04b5ce7a2.png)
# ![image.png](attachment:740f1085-aa9f-42ee-9fc8-bdc78960b336.png)

# %% [markdown]
# eger p-value degeri 0.05 ten küçük ise ilgili (h0 degerini) hipotezin hatalı oldugunu ve redettigimiz söyleyebiliriz
#
# ![image.png](attachment:ed48d713-908b-4d70-ac76-277ef57f1913.png)

# %% [markdown]
# **HİPOTEZ TESTİ ADIMLARI**

# %% [markdown]
# adım 1- hipotezlerin kurulması ve yönlerinin belirlenmesi
#
# adım 2- anlamlılık düzeyinin ve tablo degerinin belirlenmesi()
#
# adım 3-test istatistiginin belirlenmesi ve test istatistiginin hesaplanması
#
# adım 4-hesaplanan test istatistigi ile alfa'ya karşılık gelen tablo karşılaştırılır
#
# Test İstatistigi(Zh)>Tablo Degeri(Zt)ise H0 Red
#
# adım 5-Yorum

# %%
         #tek örneklem t testi
#popülasyon ortalaması ile varsayımsal bir deger arasında istatistiksel olarak anlamlı bir farklılık olup olmadıgını test etmek için kullanılan bir parametrik bir testtir
#bir ilçenin yaş ortalması ile ilgili hipotez kurmak istersek bunu kullanırız 
#mesala insanların web sitemizde geçirdigi süre ile ilgili hipotez kurmak istersek

# %% [markdown]
# ![image.png](attachment:433f4528-cf89-4242-813b-1d8dbe8077af.png)
#
# ![image.png](attachment:aa8b773e-3e5a-4f77-a03c-ae9d5550bb76.png)

# %% [markdown]
# n büyüdükçe t,y'ye yaklaşır

# %% [markdown]
# **iş uygulaması(ürün satın alma adım optimizasyonu)**
#
# ![image.png](attachment:43afb2eb-b987-44dd-a18d-626819b79e29.png)

# %% [markdown]
# #adım 1-hipotez kurulması ve yönlerinin belirlenmesi
#
# Ho:µ=20(bilinmeyen anakütle parametresi(µ),kişilerin 4. adımda geçirdigi süre 20 saniyedir)
#
# H1:µ≠20(bilinmeyen anakütle parametresi(µ),kişilerin 4. adımda geçirdigi süre 20 saniyeye eşit degildir)
#
# #adım 2- anlamlılık düzeyinin ve tablo degerinin belirlenmesi()
#
# α=0,05  , α/2=0,025(alternatif hipotezimiz var,iki yönlü hiptez kurduk,grafigin üst kısmının toplamı 0 olacaktı)
#
# Ztablo tablo olasılık degeri:0,5-0,025=0,475
#
# Ztablo kritik deger=-/+ 1,96
#
# tablodaki egri altındaki alan 1'e eşittir
# tabloda kabul edilebilir hata miktarı olasılık degeri üzerinden karşılaştırmak için kendimize bir kritik deger hesaplamış oluyoruz
#
# ![image.png](attachment:1e978438-6835-4308-b6bc-da846cb460a3.png)
#
# #adım 3-test istatistiginin belirlenmesi ve test istatistiginin hesaplanması
#
# ![image.png](attachment:383552b1-f4b6-4246-a3fe-56e2f06b852d.png)
#
# #adım 4-hesaplanan test istatistigi ile alfa'ya karşılık gelen tablo karşılaştırılır
#
# Test İstatistigi(Zh)>Tablo Degeri(Zt)ise H0 Red
#
# ![image.png](attachment:d5364dbf-3011-458a-bdbc-3aed544017e6.png)
#
# yeşil yerler karar noktalarını ifade ediyor,eger elimizde pozitif bir Zhesap degeri olmuş olsaydı grafigin sag tarafını incelerdik(1,96)!

# %% [markdown]
# ![image.png](attachment:b26aa3eb-1f98-4286-88ab-46db395b0385.png)
